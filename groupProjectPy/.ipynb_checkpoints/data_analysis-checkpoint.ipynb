# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import metrics
from keras.models import Sequential
import keras
from keras.layers import Dense
from keras.callbacks import EarlyStopping
import random

from keras import regularizers
import keras_tuner as kt
from keras.layers import BatchNormalization 
from sklearn import svm, datasets
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.multiclass import OneVsRestClassifier
from itertools import cycle

# %%
# loading csv
df_loader = pd.read_csv('spotify_songs.csv')

# %%
# displaying dataframe 
df_loader = shuffle(df_loader)
pd.set_option('display.max_columns', 1000)
df_loader.head()
# Out:
#                      track_id             track_name         track_artist  \
# 24225  3IuJXTVipz0DGz70MaCfgW          You Remind Me        Mary J. Blige
# 17761  3vDLsRfjYfsjqLelscTVh3            Buena Vibra       Mario Bautista
# 19518  3vdb5GCE9MRsRcHf3t8UdQ                     DM         The Rudeboyz
# 14468  6nbWsD9NuzBYxn52iRLRBL        Two Fine People  Yusuf / Cat Stevens
# 16178  3IRovqSVYx3CNtDWRebsET  Alive - 2006 Remaster               P.O.D.
#
#        track_popularity          track_album_id  \
# 24225                47  5Q3xLiKnY4ShDuQda7qfg2
# 17761                64  2h0VcRKYrfkBHMH2rYEZrt
# 19518                46  0eDayH6fHg4EM7QUpHXsLY
# 14468                23  5BDqJzTLIb2J85U8DA9g29
# 16178                57  1i3YXOzNkaykTt6CxWGOOU
#
#                          track_album_name track_album_release_date  \
# 24225                     What's The 411?               1992-01-01
# 17761                         Buena Vibra               2019-12-06
# 19518                                  DM               2019-04-12
# 14468                       Greatest Hits               1975-01-01
# 16178  Greatest Hits [The Atlantic Years]               2006-10-27
#
#                                        playlist_name             playlist_id  \
# 24225          New Jack Swing/ R&B Hits: 1987 - 2002  4sji14lrB5bgcr51lPALYH
# 17761                               Latin Pop Rising  37i9dQZF1DX8womvTyUjrN
# 19518                                 Todo Reggaeton  4csIMGPI3aGo3Xy7WG8jBi
# 14468  I didn’t know perm stood for permanent (wave)  3e6gYPyrTbaB8BWgSHCt5j
# 16178                               2000's hard rock  0EmGNFBBgqLmvdQGPbgiMp
#
#       playlist_genre playlist_subgenre  danceability  energy  key  loudness  \
# 24225            r&b    new jack swing         0.656   0.768   11    -4.949
# 17761          latin         latin pop         0.765   0.721    0    -5.166
# 19518          latin         reggaeton         0.844   0.675    5    -3.251
# 14468           rock    permanent wave         0.688   0.686    9    -8.640
# 16178           rock         hard rock         0.409   0.952    2    -3.761
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 24225     0       0.0593      0.259000          0.000004    0.0944    0.507
# 17761     1       0.0917      0.027800          0.000000    0.1200    0.691
# 19518     0       0.0737      0.302000          0.000357    0.1840    0.771
# 14468     1       0.0743      0.458000          0.000072    0.2000    0.757
# 16178     0       0.0756      0.000012          0.000156    0.3100    0.550
#
#          tempo  duration_ms
# 24225   95.067       258093
# 17761  105.992       159248
# 19518   96.031       215000
# 14468  150.140       215840
# 16178   80.899       203693

# %%
# checking for null values
for col in df_loader.columns:
    sum_null = df_loader[col].isna().sum()
    print(col + ": " + str(sum_null))
# Out:
# track_id: 0
# track_name: 5
# track_artist: 5
# track_popularity: 0
# track_album_id: 0
# track_album_name: 5
# track_album_release_date: 0
# playlist_name: 0
# playlist_id: 0
# playlist_genre: 0
# playlist_subgenre: 0
# danceability: 0
# energy: 0
# key: 0
# loudness: 0
# mode: 0
# speechiness: 0
# acousticness: 0
# instrumentalness: 0
# liveness: 0
# valence: 0
# tempo: 0
# duration_ms: 0

# %%
# removing rows with null values
df_loader = df_loader.dropna()
df_loader.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32828.000000  32828.000000  32828.000000  32828.000000
# mean          42.483551      0.654850      0.698603      5.373949
# std           24.980476      0.145092      0.180916      3.611572
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32828.000000  32828.000000  32828.000000  32828.000000
# mean      -6.719529      0.565737      0.107053      0.175352
# std        2.988641      0.495667      0.101307      0.219644
# min      -46.448000      0.000000      0.000000      0.000000
# 25%       -8.171250      0.000000      0.041000      0.015100
# 50%       -6.166000      1.000000      0.062500      0.080400
# 75%       -4.645000      1.000000      0.132000      0.255000
# max        1.275000      1.000000      0.918000      0.994000
#
#        instrumentalness      liveness       valence         tempo  \
# count      32828.000000  32828.000000  32828.000000  32828.000000
# mean           0.084760      0.190175      0.510556    120.883642
# std            0.224245      0.154313      0.233152     26.903632
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.092700      0.331000     99.961000
# 50%            0.000016      0.127000      0.512000    121.984000
# 75%            0.004830      0.248000      0.693000    133.918250
# max            0.994000      0.996000      0.991000    239.440000
#
#          duration_ms
# count   32828.000000
# mean   225796.829779
# std     59836.492346
# min      4000.000000
# 25%    187804.500000
# 50%    216000.000000
# 75%    253581.250000
# max    517810.000000

# %%
# array containing column names for different features relating to a song
characteristics = list(df_loader.select_dtypes(include=['int','float']).columns)
characteristics.remove("track_popularity")
characteristics.remove("mode")
print(characteristics)
# Out:
# ['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']

# %%
def showViolinPlot(data_frame,x_axis,y_axis):
    '''
        Displaying violin plot using seaborn
        Parameters:
            Dataframe - contains the desired data
            x-axis - Column from said dataframe to be plotted on x-axis
            y-axis - Column from said dataframe to be plotted on y-axis
        Returns:
            Nothing, but shows the plot
    '''
    sns.violinplot(x=data_frame[x_axis], y = data_frame[y_axis])
    plt.show()

# %%
for characteristic in characteristics:
    showViolinPlot(df_loader,'playlist_genre',characteristic)

# %%
# new df with no outliers
df_clean = df_loader.copy()

# %%
def removeOutliers(characteristic):
    medians = df_clean.groupby('playlist_genre')[characteristic].transform('median')
    df_clean[characteristic] = df_clean[characteristic].mask(lambda s: (s - s.mean()).abs() > s.std(), medians)
    #showViolinPlot(df_clean,'playlist_genre',characteristic)

# %%
# plotting violin graph for df with no outliers.
# duplicate graphs for some reason
for characteristic in characteristics:
    removeOutliers(characteristic)
    showViolinPlot(df_clean,'playlist_genre',characteristic)

# %%
df_clean.head()
# Out:
#                      track_id             track_name         track_artist  \
# 24225  3IuJXTVipz0DGz70MaCfgW          You Remind Me        Mary J. Blige
# 17761  3vDLsRfjYfsjqLelscTVh3            Buena Vibra       Mario Bautista
# 19518  3vdb5GCE9MRsRcHf3t8UdQ                     DM         The Rudeboyz
# 14468  6nbWsD9NuzBYxn52iRLRBL        Two Fine People  Yusuf / Cat Stevens
# 16178  3IRovqSVYx3CNtDWRebsET  Alive - 2006 Remaster               P.O.D.
#
#        track_popularity          track_album_id  \
# 24225                47  5Q3xLiKnY4ShDuQda7qfg2
# 17761                64  2h0VcRKYrfkBHMH2rYEZrt
# 19518                46  0eDayH6fHg4EM7QUpHXsLY
# 14468                23  5BDqJzTLIb2J85U8DA9g29
# 16178                57  1i3YXOzNkaykTt6CxWGOOU
#
#                          track_album_name track_album_release_date  \
# 24225                     What's The 411?               1992-01-01
# 17761                         Buena Vibra               2019-12-06
# 19518                                  DM               2019-04-12
# 14468                       Greatest Hits               1975-01-01
# 16178  Greatest Hits [The Atlantic Years]               2006-10-27
#
#                                        playlist_name             playlist_id  \
# 24225          New Jack Swing/ R&B Hits: 1987 - 2002  4sji14lrB5bgcr51lPALYH
# 17761                               Latin Pop Rising  37i9dQZF1DX8womvTyUjrN
# 19518                                 Todo Reggaeton  4csIMGPI3aGo3Xy7WG8jBi
# 14468  I didn’t know perm stood for permanent (wave)  3e6gYPyrTbaB8BWgSHCt5j
# 16178                               2000's hard rock  0EmGNFBBgqLmvdQGPbgiMp
#
#       playlist_genre playlist_subgenre  danceability  energy  key  loudness  \
# 24225            r&b    new jack swing         0.656   0.768    6    -4.949
# 17761          latin         latin pop         0.765   0.721    6    -5.166
# 19518          latin         reggaeton         0.729   0.675    5    -5.751
# 14468           rock    permanent wave         0.688   0.686    5    -8.640
# 16178           rock         hard rock         0.523   0.775    2    -3.761
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 24225     0       0.0593      0.259000          0.000004    0.0944    0.507
# 17761     1       0.0917      0.027800          0.000000    0.1200    0.691
# 19518     0       0.0737      0.302000          0.000357    0.1840    0.628
# 14468     1       0.0743      0.037300          0.000072    0.2000    0.531
# 16178     0       0.0756      0.000012          0.000156    0.3100    0.550
#
#          tempo  duration_ms
# 24225   95.067       258093
# 17761  105.992       210730
# 19518   96.031       215000
# 14468  124.035       215840
# 16178  124.035       203693

# %%
encoder_map = {
  "playlist_genre" : {
    "values" : [],
    "uniques" : [],
  },
  "playlist_subgenre" : {
    "values" : [],
    "uniques" : [],
  }}
def encoder(label):
    values, uniques = pd.factorize(df_clean[label]) 
    df_clean[label] = values
    encoder_map[label]["values"], encoder_map[label]["uniques"] = values,uniques

encoder("playlist_genre")
encoder("playlist_subgenre")

# %%
print(encoder_map["playlist_genre"]["values"])
print(encoder_map["playlist_genre"]["uniques"])
# Out:
# [0 1 1 ... 2 0 4]
# Index(['r&b', 'latin', 'rock', 'edm', 'rap', 'pop'], dtype='object')

# %%
df_clean.head()
# Out:
#                      track_id             track_name         track_artist  \
# 24225  3IuJXTVipz0DGz70MaCfgW          You Remind Me        Mary J. Blige
# 17761  3vDLsRfjYfsjqLelscTVh3            Buena Vibra       Mario Bautista
# 19518  3vdb5GCE9MRsRcHf3t8UdQ                     DM         The Rudeboyz
# 14468  6nbWsD9NuzBYxn52iRLRBL        Two Fine People  Yusuf / Cat Stevens
# 16178  3IRovqSVYx3CNtDWRebsET  Alive - 2006 Remaster               P.O.D.
#
#        track_popularity          track_album_id  \
# 24225                47  5Q3xLiKnY4ShDuQda7qfg2
# 17761                64  2h0VcRKYrfkBHMH2rYEZrt
# 19518                46  0eDayH6fHg4EM7QUpHXsLY
# 14468                23  5BDqJzTLIb2J85U8DA9g29
# 16178                57  1i3YXOzNkaykTt6CxWGOOU
#
#                          track_album_name track_album_release_date  \
# 24225                     What's The 411?               1992-01-01
# 17761                         Buena Vibra               2019-12-06
# 19518                                  DM               2019-04-12
# 14468                       Greatest Hits               1975-01-01
# 16178  Greatest Hits [The Atlantic Years]               2006-10-27
#
#                                        playlist_name             playlist_id  \
# 24225          New Jack Swing/ R&B Hits: 1987 - 2002  4sji14lrB5bgcr51lPALYH
# 17761                               Latin Pop Rising  37i9dQZF1DX8womvTyUjrN
# 19518                                 Todo Reggaeton  4csIMGPI3aGo3Xy7WG8jBi
# 14468  I didn’t know perm stood for permanent (wave)  3e6gYPyrTbaB8BWgSHCt5j
# 16178                               2000's hard rock  0EmGNFBBgqLmvdQGPbgiMp
#
#        playlist_genre  playlist_subgenre  danceability  energy  key  loudness  \
# 24225               0                  0         0.656   0.768    6    -4.949
# 17761               1                  1         0.765   0.721    6    -5.166
# 19518               1                  2         0.729   0.675    5    -5.751
# 14468               2                  3         0.688   0.686    5    -8.640
# 16178               2                  4         0.523   0.775    2    -3.761
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 24225     0       0.0593      0.259000          0.000004    0.0944    0.507
# 17761     1       0.0917      0.027800          0.000000    0.1200    0.691
# 19518     0       0.0737      0.302000          0.000357    0.1840    0.628
# 14468     1       0.0743      0.037300          0.000072    0.2000    0.531
# 16178     0       0.0756      0.000012          0.000156    0.3100    0.550
#
#          tempo  duration_ms
# 24225   95.067       258093
# 17761  105.992       210730
# 19518   96.031       215000
# 14468  124.035       215840
# 16178  124.035       203693

# %%
df_for_ann = df_clean.iloc[:, 11:-1].copy()
df_for_ann.head()
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 24225         0.656   0.768    6    -4.949     0       0.0593      0.259000
# 17761         0.765   0.721    6    -5.166     1       0.0917      0.027800
# 19518         0.729   0.675    5    -5.751     0       0.0737      0.302000
# 14468         0.688   0.686    5    -8.640     1       0.0743      0.037300
# 16178         0.523   0.775    2    -3.761     0       0.0756      0.000012
#
#        instrumentalness  liveness  valence    tempo
# 24225          0.000004    0.0944    0.507   95.067
# 17761          0.000000    0.1200    0.691  105.992
# 19518          0.000357    0.1840    0.628   96.031
# 14468          0.000072    0.2000    0.531  124.035
# 16178          0.000156    0.3100    0.550  124.035

# %%
scaler = preprocessing.MinMaxScaler()
df_for_ann[df_for_ann.columns] = scaler.fit_transform(df_for_ann[df_for_ann.columns])
df_for_ann.head()
# Out:
#        danceability    energy       key  loudness  mode  speechiness  \
# 24225      0.505190  0.692521  0.666667  0.796219   0.0     0.198815
# 17761      0.882353  0.562327  0.666667  0.759913   1.0     0.373384
# 19518      0.757785  0.434903  0.500000  0.662038   0.0     0.276401
# 14468      0.615917  0.465374  0.500000  0.178685   1.0     0.279634
# 16178      0.044983  0.711911  0.000000  0.994981   0.0     0.286638
#
#        acousticness  instrumentalness  liveness   valence     tempo
# 24225      0.657360          0.000013  0.189873  0.492473  0.020185
# 17761      0.070558          0.000000  0.272963  0.888172  0.223244
# 19518      0.766497          0.001155  0.480688  0.752688  0.038103
# 14468      0.094670          0.000234  0.532619  0.544086  0.558604
# 16178      0.000031          0.000505  0.889646  0.584946  0.558604

# %%
y = df_clean["playlist_genre"]
X = df_for_ann
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.33, random_state = 1)

# %%
input_shape_0 = len(list(X.columns))

# %%
from keras.layers import Flatten

def model_builder(hp):
    '''
        Outline of the model, defining the options for the keras tuner
        Parameters:
            hp - Internally passed object. instantiates the Hyperparameter
                    object of the keras tuner
        Returns: 
            Building blocks for model
    '''
    model = Sequential()
    model.add(Flatten(input_shape = (input_shape_0,)))
    hp_activation = hp.Choice('activation', values = ['LeakyReLU','elu','gelu']) 
    hp_layer_1 = hp.Int('layer_1', min_value = 0, max_value = 512, step = 16)
    hp_layer_2 = hp.Int('layer_2', min_value = 0, max_value = 512, step = 16)
#     hp_layer_3 = hp.Int('layer_3', min_value = 0, max_value = 512, step = 16)
#    hp_layer_4 = hp.Int('layer_4', min_value = 0, max_value = 512, step = 16)

    hp_learning_rate = hp.Choice('learning_rate', values = [0.01, 0.001, 0.0001])

    model.add(Dense(units = hp_layer_1, activation = hp_activation))
    
    model.add(Dense(units = hp_layer_2, activation = hp_activation, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4),
    bias_regularizer=regularizers.L2(1e-4),
    activity_regularizer=regularizers.L2(1e-5)))
    
#     model.add(Dense(units = hp_layer_3, activation = hp_activation, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4),
#     bias_regularizer=regularizers.L2(1e-4),
#     activity_regularizer=regularizers.L2(1e-5)))
    
#     model.add(Dense(units = hp_layer_4, activation = hp_activation, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4),
#     bias_regularizer=regularizers.L2(1e-4),
#     activity_regularizer=regularizers.L2(1e-5)))
    
#     if(prediction_column == 'price_m2'):
#         model.add(Dense(1, activation='linear'))
#         model.compile(optimizer = keras.optimizers.Nadam(learning_rate=hp_learning_rate), 
#                   loss='mean_squared_error', 
#                   metrics = ['mean_absolute_percentage_error'] ) 
    model.add(BatchNormalization())
    model.add(Dense(len(encoder_map["playlist_genre"]["uniques"]), activation = 'softmax'))
    model.compile(optimizer = keras.optimizers.Nadam(learning_rate=hp_learning_rate),                  
                      loss='sparse_categorical_crossentropy', 
                      metrics = ['accuracy'] )
    return model

# %%
objective_value = 'val_accuracy'
monitor_value = 'val_loss'
trials = 16
restore_flag = True
patience_value = 3
validation_value = 0.21
project = 'playlistGenre_without_duration'
overwrite_bool = True
    
tuner = kt.RandomSearch(
    model_builder,
    objective = objective_value,
    max_trials=trials,
    directory='dir',
    overwrite=False,
    project_name=project
)

# %%
es = keras.callbacks.EarlyStopping(
                                   monitor = monitor_value,
                                   mode='auto',
                                   patience=patience_value, 
                                   restore_best_weights = restore_flag)

# %%
tuner.search(X_train, y_train, epochs = 100,
            validation_split = validation_value,
            callbacks = [es])
# Out:
# Trial 16 Complete [00h 02m 18s]
# val_accuracy: 0.738688051700592
#
# Best val_accuracy So Far: 0.7389045357704163
# Total elapsed time: 00h 28m 06s

# %%
hyper_parameters = tuner.get_best_hyperparameters(num_trials = 1)[0]
model = tuner.hypermodel.build(hyper_parameters)
print(model)
history = model.fit(X_train, y_train, epochs = 150, 
                    validation_split = validation_value, 
                    shuffle = True,
                    callbacks = [es])
# Out:
# <keras.src.engine.sequential.Sequential object at 0x000001F8C2687D60>
# Epoch 1/150
# 543/543 [==============================] - 9s 8ms/step - loss: 1.3512 - accuracy: 0.5227 - val_loss: 1.2923 - val_accuracy: 0.5501
# Epoch 2/150
# 543/543 [==============================] - 4s 7ms/step - loss: 1.2764 - accuracy: 0.5488 - val_loss: 1.2347 - val_accuracy: 0.5594
# Epoch 3/150
# 543/543 [==============================] - 3s 6ms/step - loss: 1.2348 - accuracy: 0.5688 - val_loss: 1.1943 - val_accuracy: 0.5763
# Epoch 4/150
# 543/543 [==============================] - 3s 6ms/step - loss: 1.1994 - accuracy: 0.5790 - val_loss: 1.1689 - val_accuracy: 0.5848
# Epoch 5/150
# 543/543 [==============================] - 4s 7ms/step - loss: 1.1627 - accuracy: 0.5905 - val_loss: 1.1421 - val_accuracy: 0.5969
# Epoch 6/150
# 543/543 [==============================] - 3s 6ms/step - loss: 1.1192 - accuracy: 0.6101 - val_loss: 1.0947 - val_accuracy: 0.6127
# Epoch 7/150
# 543/543 [==============================] - 4s 7ms/step - loss: 1.0791 - accuracy: 0.6210 - val_loss: 1.0574 - val_accuracy: 0.6313
# Epoch 8/150
# 543/543 [==============================] - 4s 7ms/step - loss: 1.0408 - accuracy: 0.6361 - val_loss: 1.0150 - val_accuracy: 0.6469
# Epoch 9/150
# 543/543 [==============================] - 4s 7ms/step - loss: 1.0095 - accuracy: 0.6466 - val_loss: 0.9747 - val_accuracy: 0.6601
# Epoch 10/150
# 543/543 [==============================] - 4s 7ms/step - loss: 0.9890 - accuracy: 0.6527 - val_loss: 0.9853 - val_accuracy: 0.6549
# Epoch 11/150
# 543/543 [==============================] - 3s 6ms/step - loss: 0.9639 - accuracy: 0.6614 - val_loss: 1.0080 - val_accuracy: 0.6384
# Epoch 12/150
# 543/543 [==============================] - 4s 8ms/step - loss: 0.9425 - accuracy: 0.6691 - val_loss: 0.9285 - val_accuracy: 0.6800
# Epoch 13/150
# 543/543 [==============================] - 3s 6ms/step - loss: 0.9292 - accuracy: 0.6712 - val_loss: 0.9106 - val_accuracy: 0.6856
# Epoch 14/150
# 543/543 [==============================] - 3s 6ms/step - loss: 0.9123 - accuracy: 0.6809 - val_loss: 0.9280 - val_accuracy: 0.6796
# Epoch 15/150
# 543/543 [==============================] - 3s 6ms/step - loss: 0.9005 - accuracy: 0.6831 - val_loss: 0.8739 - val_accuracy: 0.7038
# Epoch 16/150
# 543/543 [==============================] - 4s 8ms/step - loss: 0.8859 - accuracy: 0.6932 - val_loss: 0.8531 - val_accuracy: 0.7082
# Epoch 17/150
# 543/543 [==============================] - 3s 6ms/step - loss: 0.8748 - accuracy: 0.6974 - val_loss: 0.8490 - val_accuracy: 0.7030
# Epoch 18/150
# 543/543 [==============================] - 4s 7ms/step - loss: 0.8624 - accuracy: 0.7013 - val_loss: 0.8477 - val_accuracy: 0.7103
# Epoch 19/150
# 543/543 [==============================] - 3s 6ms/step - loss: 0.8520 - accuracy: 0.7058 - val_loss: 0.8383 - val_accuracy: 0.7049
# Epoch 20/150
# 543/543 [==============================] - 4s 8ms/step - loss: 0.8400 - accuracy: 0.7068 - val_loss: 0.8387 - val_accuracy: 0.7110
# Epoch 21/150
# 543/543 [==============================] - 3s 6ms/step - loss: 0.8329 - accuracy: 0.7137 - val_loss: 0.8273 - val_accuracy: 0.7218
# Epoch 22/150
# 543/543 [==============================] - 4s 8ms/step - loss: 0.8277 - accuracy: 0.7163 - val_loss: 0.8218 - val_accuracy: 0.7225
# Epoch 23/150
# 543/543 [==============================] - 4s 7ms/step - loss: 0.8133 - accuracy: 0.7205 - val_loss: 0.8505 - val_accuracy: 0.7053
# Epoch 24/150
# 543/543 [==============================] - 4s 7ms/step - loss: 0.8090 - accuracy: 0.7180 - val_loss: 0.8119 - val_accuracy: 0.7205
# Epoch 25/150
# 543/543 [==============================] - 4s 8ms/step - loss: 0.8042 - accuracy: 0.7245 - val_loss: 0.8182 - val_accuracy: 0.7196
# Epoch 26/150
# 543/543 [==============================] - 4s 8ms/step - loss: 0.7990 - accuracy: 0.7268 - val_loss: 0.7809 - val_accuracy: 0.7337
# Epoch 27/150
# 543/543 [==============================] - 4s 7ms/step - loss: 0.7866 - accuracy: 0.7282 - val_loss: 0.7927 - val_accuracy: 0.7287
# Epoch 28/150
# 543/543 [==============================] - 4s 8ms/step - loss: 0.7793 - accuracy: 0.7333 - val_loss: 0.7682 - val_accuracy: 0.7352
# Epoch 29/150
# 543/543 [==============================] - 4s 7ms/step - loss: 0.7786 - accuracy: 0.7319 - val_loss: 0.7887 - val_accuracy: 0.7370
# Epoch 30/150
# 543/543 [==============================] - 4s 7ms/step - loss: 0.7710 - accuracy: 0.7373 - val_loss: 0.7798 - val_accuracy: 0.7341
# Epoch 31/150
# 543/543 [==============================] - 4s 8ms/step - loss: 0.7711 - accuracy: 0.7404 - val_loss: 0.7593 - val_accuracy: 0.7417
# Epoch 32/150
# 543/543 [==============================] - 4s 8ms/step - loss: 0.7739 - accuracy: 0.7324 - val_loss: 0.7761 - val_accuracy: 0.7383
# Epoch 33/150
# 543/543 [==============================] - 4s 8ms/step - loss: 0.7628 - accuracy: 0.7378 - val_loss: 0.7664 - val_accuracy: 0.7400
# Epoch 34/150
# 543/543 [==============================] - 4s 7ms/step - loss: 0.7573 - accuracy: 0.7366 - val_loss: 0.7670 - val_accuracy: 0.7361

# %%
for k,v in hyper_parameters.values.items():
    print(f'{k} : {v}')
# Out:
# activation : LeakyReLU
# layer_1 : 144
# layer_2 : 464
# learning_rate : 0.001

# %%
history_dict = history.history
print(history_dict.keys())

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, val_acc, label='Validation accuracy', color='blue')
plt.plot(epochs, acc, label='Training accuracy',color='orange')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(epochs, loss, label='Loss', color = 'red')
plt.plot(epochs, val_loss, label='Validation Loss', color = 'purple')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# commented out as they take ages
# g = sns.PairGrid(df_loader, hue="playlist_genre")
# g.map(sns.scatterplot)
