# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import metrics
from keras.models import Sequential
import keras
from keras.layers import Dense
from keras.callbacks import EarlyStopping
import random
from sklearn.ensemble import RandomForestRegressor
from keras import regularizers
import keras_tuner as kt
from keras.layers import BatchNormalization 
from sklearn import svm, datasets
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.multiclass import OneVsRestClassifier
from itertools import cycle

# %%
# loading csv
df_loader = pd.read_csv('spotify_songs.csv')

# %%
# displaying dataframe 
df_loader = shuffle(df_loader)
pd.set_option('display.max_columns', 1000)
df_loader.head()
# Out:
#                      track_id                                  track_name  \
# 19242  0UQwlF2pRkr1lMN6kNNUj3                                     La Boca
# 4414   0POuQCMT4zyRzB2MjbzVaI                                   Bad Vibes
# 11870  0eti3iRdEgUxwcIcN2N9DY                      Domino - 1999 Remaster
# 21203  6UUzt6LPtVNwy8l6jqu9C9  You're The One That I Want - From “Grease”
# 9104   6Ij42HHAMo8ZsvdAMTWTpU                                   The Heist
#
#         track_artist  track_popularity          track_album_id  \
# 19242    Mau y Ricky                80  01yYW0rRRwlEZx1dMmc5ff
# 4414          K.Flay                55  1CJDBCPg27ASz4eWE7oeNz
# 11870   Van Morrison                58  3YdFToTF5Mr2HLx7zRUIQA
# 21203  John Travolta                10  24xwaPVl6xkUunl6lEWwje
# 9104           Big L                 0  5wjwhf9XgsJMNpK7ZMOO3j
#
#                          track_album_name track_album_release_date  \
# 19242       Para Aventuras y Curiosidades               2019-05-03
# 4414                            Solutions               2019-07-12
# 11870       His Band and the Street Choir               1970-11-15
# 21203                                Gold               2005-01-01
# 9104   The Big Picture (Explicit Version)               2000-08-01
#
#                              playlist_name             playlist_id  \
# 19242                       Verano Forever  37i9dQZF1DXdnGF35OawbN
# 4414               2019 in Indie Poptimism  16RNbqnNCCLlBJti7JU5nc
# 11870  70s Pop & Rock Hits and Deep Tracks  1uKFRCQYci8kVgMy3xzTVH
# 21203    School Dance 2019 (Squeaky Clean)  0SqaMfNsngZCpPw0UuelA7
# 9104              90s Hiphop / Gangsta Rap  5yGuoOwRQF3o8NVRRlvCj7
#
#       playlist_genre playlist_subgenre  danceability  energy  key  loudness  \
# 19242          latin         reggaeton         0.618   0.795    2    -1.800
# 4414             pop   indie poptimism         0.716   0.727   10    -6.734
# 11870           rock        album rock         0.731   0.555    2   -13.684
# 21203          latin     latin hip hop         0.743   0.774    0    -5.916
# 9104             rap      gangster rap         0.852   0.634    1    -9.924
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 19242     1       0.1130       0.06550          0.000000    0.3090    0.760
# 4414      1       0.2960       0.02640          0.000000    0.0717    0.597
# 11870     1       0.0519       0.32100          0.000103    0.0527    0.935
# 21203     1       0.0941       0.25600          0.000050    0.1550    0.833
# 9104      1       0.3960       0.00382          0.000000    0.1110    0.813
#
#          tempo  duration_ms
# 19242  185.901       206279
# 4414    97.977       185907
# 11870  131.260       189427
# 21203  106.564       167613
# 9104    93.724       182555

# %%
# checking for null values
for col in df_loader.columns:
    sum_null = df_loader[col].isna().sum()
    print(col + ": " + str(sum_null))
# Out:
# track_id: 0
# track_name: 5
# track_artist: 5
# track_popularity: 0
# track_album_id: 0
# track_album_name: 5
# track_album_release_date: 0
# playlist_name: 0
# playlist_id: 0
# playlist_genre: 0
# playlist_subgenre: 0
# danceability: 0
# energy: 0
# key: 0
# loudness: 0
# mode: 0
# speechiness: 0
# acousticness: 0
# instrumentalness: 0
# liveness: 0
# valence: 0
# tempo: 0
# duration_ms: 0

# %%
# removing rows with null values
df_loader = df_loader.dropna()
df_loader.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32828.000000  32828.000000  32828.000000  32828.000000
# mean          42.483551      0.654850      0.698603      5.373949
# std           24.980476      0.145092      0.180916      3.611572
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32828.000000  32828.000000  32828.000000  32828.000000
# mean      -6.719529      0.565737      0.107053      0.175352
# std        2.988641      0.495667      0.101307      0.219644
# min      -46.448000      0.000000      0.000000      0.000000
# 25%       -8.171250      0.000000      0.041000      0.015100
# 50%       -6.166000      1.000000      0.062500      0.080400
# 75%       -4.645000      1.000000      0.132000      0.255000
# max        1.275000      1.000000      0.918000      0.994000
#
#        instrumentalness      liveness       valence         tempo  \
# count      32828.000000  32828.000000  32828.000000  32828.000000
# mean           0.084760      0.190175      0.510556    120.883642
# std            0.224245      0.154313      0.233152     26.903632
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.092700      0.331000     99.961000
# 50%            0.000016      0.127000      0.512000    121.984000
# 75%            0.004830      0.248000      0.693000    133.918250
# max            0.994000      0.996000      0.991000    239.440000
#
#          duration_ms
# count   32828.000000
# mean   225796.829779
# std     59836.492346
# min      4000.000000
# 25%    187804.500000
# 50%    216000.000000
# 75%    253581.250000
# max    517810.000000

# %%
# array containing column names for different features relating to a song
characteristics = list(df_loader.select_dtypes(include=['int','float']).columns)
characteristics.remove("track_popularity")
characteristics.remove("mode")
print(characteristics)
# Out:
# ['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']

# %%
def showViolinPlot(data_frame,x_axis,y_axis):
    '''
        Displaying violin plot using seaborn
        Parameters:
            Dataframe - contains the desired data
            x-axis - Column from said dataframe to be plotted on x-axis
            y-axis - Column from said dataframe to be plotted on y-axis
        Returns:
            Nothing, but shows the plot
    '''
    sns.violinplot(x=data_frame[x_axis], y = data_frame[y_axis])
    plt.show()

# %%
for characteristic in characteristics:
    showViolinPlot(df_loader,'playlist_genre',characteristic)

# %%
# new df with no outliers
df_clean = df_loader.copy()

# %%
def removeOutliers(characteristic):
    medians = df_clean.groupby('playlist_genre')[characteristic].transform('median')
    df_clean[characteristic] = df_clean[characteristic].mask(lambda s: (s - s.mean()).abs() > s.std(), medians)
    #showViolinPlot(df_clean,'playlist_genre',characteristic)

# %%
# plotting violin graph for df with no outliers.
# duplicate graphs for some reason
for characteristic in characteristics:
    removeOutliers(characteristic)
    showViolinPlot(df_clean,'playlist_genre',characteristic)

# %%
df_clean.head()
# Out:
#                      track_id                                  track_name  \
# 19242  0UQwlF2pRkr1lMN6kNNUj3                                     La Boca
# 4414   0POuQCMT4zyRzB2MjbzVaI                                   Bad Vibes
# 11870  0eti3iRdEgUxwcIcN2N9DY                      Domino - 1999 Remaster
# 21203  6UUzt6LPtVNwy8l6jqu9C9  You're The One That I Want - From “Grease”
# 9104   6Ij42HHAMo8ZsvdAMTWTpU                                   The Heist
#
#         track_artist  track_popularity          track_album_id  \
# 19242    Mau y Ricky                80  01yYW0rRRwlEZx1dMmc5ff
# 4414          K.Flay                55  1CJDBCPg27ASz4eWE7oeNz
# 11870   Van Morrison                58  3YdFToTF5Mr2HLx7zRUIQA
# 21203  John Travolta                10  24xwaPVl6xkUunl6lEWwje
# 9104           Big L                 0  5wjwhf9XgsJMNpK7ZMOO3j
#
#                          track_album_name track_album_release_date  \
# 19242       Para Aventuras y Curiosidades               2019-05-03
# 4414                            Solutions               2019-07-12
# 11870       His Band and the Street Choir               1970-11-15
# 21203                                Gold               2005-01-01
# 9104   The Big Picture (Explicit Version)               2000-08-01
#
#                              playlist_name             playlist_id  \
# 19242                       Verano Forever  37i9dQZF1DXdnGF35OawbN
# 4414               2019 in Indie Poptimism  16RNbqnNCCLlBJti7JU5nc
# 11870  70s Pop & Rock Hits and Deep Tracks  1uKFRCQYci8kVgMy3xzTVH
# 21203    School Dance 2019 (Squeaky Clean)  0SqaMfNsngZCpPw0UuelA7
# 9104              90s Hiphop / Gangsta Rap  5yGuoOwRQF3o8NVRRlvCj7
#
#       playlist_genre playlist_subgenre  danceability  energy  key  loudness  \
# 19242          latin         reggaeton         0.618   0.795    2    -5.751
# 4414             pop   indie poptimism         0.716   0.727    5    -6.734
# 11870           rock        album rock         0.731   0.555    2    -7.007
# 21203          latin     latin hip hop         0.743   0.774    6    -5.916
# 9104             rap      gangster rap         0.737   0.634    6    -6.508
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 19242     1       0.1130       0.06550          0.000000    0.3090    0.628
# 4414      1       0.0490       0.02640          0.000000    0.0717    0.597
# 11870     1       0.0519       0.32100          0.000103    0.0527    0.531
# 21203     1       0.0941       0.25600          0.000050    0.1550    0.628
# 9104      1       0.1770       0.00382          0.000000    0.1110    0.517
#
#          tempo  duration_ms
# 19242  110.962       206279
# 4414    97.977       185907
# 11870  131.260       189427
# 21203  106.564       167613
# 9104   119.988       182555

# %%
# don't run twice
encoder_map = {
  "playlist_genre" : {
    "values" : [],
    "uniques" : [],
  },
  "playlist_subgenre" : {
    "values" : [],
    "uniques" : [],
  }}
def encoder(label):
    values, uniques = pd.factorize(df_clean[label]) 
    df_clean[label] = values
    encoder_map[label]["values"], encoder_map[label]["uniques"] = values,uniques

encoder("playlist_genre")
encoder("playlist_subgenre")

import pickle 

with open('saved_dictionary.pkl', 'wb') as f:
    pickle.dump(encoder_map, f)

# %%
print(encoder_map["playlist_subgenre"]["values"])
print(encoder_map["playlist_subgenre"]["uniques"])
# Out:
# [ 0  1  2 ...  1 17 12]
# Index(['reggaeton', 'indie poptimism', 'album rock', 'latin hip hop',
#        'gangster rap', 'trap', 'hip hop', 'latin pop', 'new jack swing',
#        'big room', 'electro house', 'southern hip hop',
#        'progressive electro house', 'hip pop', 'permanent wave', 'hard rock',
#        'urban contemporary', 'neo soul', 'pop edm', 'electropop', 'tropical',
#        'post-teen pop', 'classic rock', 'dance pop'],
#       dtype='object')

# %%
df_clean.head()
# Out:
#                      track_id                                  track_name  \
# 19242  0UQwlF2pRkr1lMN6kNNUj3                                     La Boca
# 4414   0POuQCMT4zyRzB2MjbzVaI                                   Bad Vibes
# 11870  0eti3iRdEgUxwcIcN2N9DY                      Domino - 1999 Remaster
# 21203  6UUzt6LPtVNwy8l6jqu9C9  You're The One That I Want - From “Grease”
# 9104   6Ij42HHAMo8ZsvdAMTWTpU                                   The Heist
#
#         track_artist  track_popularity          track_album_id  \
# 19242    Mau y Ricky                80  01yYW0rRRwlEZx1dMmc5ff
# 4414          K.Flay                55  1CJDBCPg27ASz4eWE7oeNz
# 11870   Van Morrison                58  3YdFToTF5Mr2HLx7zRUIQA
# 21203  John Travolta                10  24xwaPVl6xkUunl6lEWwje
# 9104           Big L                 0  5wjwhf9XgsJMNpK7ZMOO3j
#
#                          track_album_name track_album_release_date  \
# 19242       Para Aventuras y Curiosidades               2019-05-03
# 4414                            Solutions               2019-07-12
# 11870       His Band and the Street Choir               1970-11-15
# 21203                                Gold               2005-01-01
# 9104   The Big Picture (Explicit Version)               2000-08-01
#
#                              playlist_name             playlist_id  \
# 19242                       Verano Forever  37i9dQZF1DXdnGF35OawbN
# 4414               2019 in Indie Poptimism  16RNbqnNCCLlBJti7JU5nc
# 11870  70s Pop & Rock Hits and Deep Tracks  1uKFRCQYci8kVgMy3xzTVH
# 21203    School Dance 2019 (Squeaky Clean)  0SqaMfNsngZCpPw0UuelA7
# 9104              90s Hiphop / Gangsta Rap  5yGuoOwRQF3o8NVRRlvCj7
#
#        playlist_genre  playlist_subgenre  danceability  energy  key  loudness  \
# 19242               0                  0         0.618   0.795    2    -5.751
# 4414                1                  1         0.716   0.727    5    -6.734
# 11870               2                  2         0.731   0.555    2    -7.007
# 21203               0                  3         0.743   0.774    6    -5.916
# 9104                3                  4         0.737   0.634    6    -6.508
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 19242     1       0.1130       0.06550          0.000000    0.3090    0.628
# 4414      1       0.0490       0.02640          0.000000    0.0717    0.597
# 11870     1       0.0519       0.32100          0.000103    0.0527    0.531
# 21203     1       0.0941       0.25600          0.000050    0.1550    0.628
# 9104      1       0.1770       0.00382          0.000000    0.1110    0.517
#
#          tempo  duration_ms
# 19242  110.962       206279
# 4414    97.977       185907
# 11870  131.260       189427
# 21203  106.564       167613
# 9104   119.988       182555

# %%
df_for_ann = df_clean.iloc[:, 9:-1].copy()
df_for_ann = df_for_ann.drop(columns = ["playlist_subgenre"]).copy()
df_for_ann.head()
# Out:
#        playlist_genre  danceability  energy  key  loudness  mode  speechiness  \
# 19242               0         0.618   0.795    2    -5.751     1       0.1130
# 4414                1         0.716   0.727    5    -6.734     1       0.0490
# 11870               2         0.731   0.555    2    -7.007     1       0.0519
# 21203               0         0.743   0.774    6    -5.916     1       0.0941
# 9104                3         0.737   0.634    6    -6.508     1       0.1770
#
#        acousticness  instrumentalness  liveness  valence    tempo
# 19242       0.06550          0.000000    0.3090    0.628  110.962
# 4414        0.02640          0.000000    0.0717    0.597   97.977
# 11870       0.32100          0.000103    0.0527    0.531  131.260
# 21203       0.25600          0.000050    0.1550    0.628  106.564
# 9104        0.00382          0.000000    0.1110    0.517  119.988

# %%
scaler = preprocessing.MinMaxScaler()
df_for_ann[df_for_ann.columns] = scaler.fit_transform(df_for_ann[df_for_ann.columns])
df_for_ann.head()
# Out:
#        playlist_genre  danceability    energy       key  loudness  mode  \
# 19242             0.0      0.373702  0.767313  0.000000  0.662038   1.0
# 4414              0.2      0.712803  0.578947  0.500000  0.497574   1.0
# 11870             0.4      0.764706  0.102493  0.000000  0.451899   1.0
# 21203             0.0      0.806228  0.709141  0.666667  0.634432   1.0
# 9104              0.6      0.785467  0.321330  0.666667  0.535386   1.0
#
#        speechiness  acousticness  instrumentalness  liveness   valence  \
# 19242     0.488147      0.166244          0.000000  0.886401  0.752688
# 4414      0.143319      0.067005          0.000000  0.116196  0.686022
# 11870     0.158944      0.814721          0.000333  0.054528  0.544086
# 21203     0.386315      0.649746          0.000163  0.386563  0.752688
# 9104      0.832974      0.009695          0.000000  0.243752  0.513978
#
#           tempo
# 19242  0.315620
# 4414   0.074272
# 11870  0.692892
# 21203  0.233876
# 9104   0.483384

# %%
def get_mean_energy_by_playlist(df):
    genres = df_for_ann["playlist_genre"].unique()
    genre_dicts = {genre: {} for genre in genres}
    for characteristic in df.columns[1:]:
        median_by_playlist_genre = df.groupby(['playlist_genre'])[characteristic].median().to_dict()
        for genre in genres:
            genre_dicts[genre][characteristic] = median_by_playlist_genre.get(genre, None)
    return genre_dicts


result = get_mean_energy_by_playlist(df_for_ann)
print(result)
# Out:
# {0.0: {'danceability': 0.7577854671280275, 'energy': 0.5844875346260388, 'key': 0.6666666666666667, 'loudness': 0.6620378116111761, 'mode': 1.0, 'speechiness': 0.24245689655172414, 'acousticness': 0.3527918781725889, 'instrumentalness': 7.669902912621361e-06, 'liveness': 0.2762090230444661, 'valence': 0.7526881720430109, 'tempo': 0.3156202371659047}, 0.2: {'danceability': 0.4913494809688581, 'energy': 0.5789473684210527, 'key': 0.49999999999999994, 'loudness': 0.6479839384306508, 'mode': 1.0, 'speechiness': 0.14331896551724138, 'acousticness': 0.19467005076142133, 'instrumentalness': 3.527508090614887e-05, 'liveness': 0.28270042194092826, 'valence': 0.4774193548387097, 'tempo': 0.48392253076093805}, 0.4: {'danceability': 0.04498269896193774, 'energy': 0.7119113573407203, 'key': 0.49999999999999994, 'loudness': 0.4518989459595115, 'mode': 1.0, 'speechiness': 0.1050646551724138, 'acousticness': 0.09467005076142132, 'instrumentalness': 0.0006828478964401295, 'liveness': 0.3248945147679325, 'valence': 0.5440860215053763, 'tempo': 0.558603769376603}, 0.6000000000000001: {'danceability': 0.7854671280276815, 'energy': 0.4072022160664821, 'key': 0.6666666666666667, 'loudness': 0.5353856449723942, 'mode': 1.0, 'speechiness': 0.8329741379310345, 'acousticness': 0.2766497461928934, 'instrumentalness': 0.0, 'liveness': 0.29892891918208375, 'valence': 0.513978494623656, 'tempo': 0.483383517341363}, 0.8: {'danceability': 0.6193771626297573, 'energy': 0.21606648199445977, 'key': 0.6666666666666667, 'loudness': 0.3828007361552619, 'mode': 1.0, 'speechiness': 0.24515086206896552, 'acousticness': 0.4187817258883249, 'instrumentalness': 1.4789644012944986e-05, 'liveness': 0.272963323596235, 'valence': 0.567741935483871, 'tempo': 0.2743950039032006}, 1.0: {'danceability': 0.5155709342560555, 'energy': 0.8642659279778395, 'key': 0.6666666666666667, 'loudness': 0.7942111427137359, 'mode': 1.0, 'speechiness': 0.20204741379310348, 'acousticness': 0.04898477157360406, 'instrumentalness': 0.012912621359223301, 'liveness': 0.33463161311262585, 'valence': 0.1978494623655913, 'tempo': 0.6147540983606556}}

# %%
correlation_matrix = df_for_ann.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title('Correlation Matrix')
plt.show()

# %%
X = df_for_ann
y = df_clean["playlist_subgenre"]

rf = RandomForestRegressor()
rf.fit(X, y)
feature_importances = pd.Series(rf.feature_importances_, index=X.columns)
feature_importances.nlargest(12).plot(kind='barh')
plt.title('Feature Importance')
plt.show()

# %%
#df_for_ann = df_for_ann.drop(columns= ["instrumentalness","liveness","acousticness","key","speechiness"]).copy()

# %%
y = df_clean["playlist_genre"]
X = df_for_ann
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25, random_state = 1)

# %%
input_shape_0 = len(list(X.columns))

# %%
from keras.layers import Flatten
# doing this allows for the best potential hyperparameters to be found
def model_builder(hp):
    '''
        Outline of the model, defining the options for the keras tuner
        Parameters:
            hp - Internally passed object. instantiates the Hyperparameter
                    object of the keras tuner
        Returns: 
            Building blocks for model
    '''
    model = Sequential()
    model.add(Flatten(input_shape = (input_shape_0,)))
    hp_activation = hp.Choice('activation', values = ['LeakyReLU','gelu']) 
    hp_layer_1 = hp.Int('layer_1', min_value = 0, max_value = 512, step = 16)
    hp_layer_2 = hp.Int('layer_2', min_value = 0, max_value = 512, step = 16)
    hp_layer_3 = hp.Int('layer_3', min_value = 0, max_value = 512, step = 16)
#hp_layer_4 = hp.Int('layer_3', min_value = 0, max_value = 512, step = 16)

    hp_learning_rate = hp.Choice('learning_rate', values = [0.01, 0.001, 0.0001])
    model.add(BatchNormalization())
    
    model.add(Dense(units = hp_layer_1, activation = hp_activation, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4),
    bias_regularizer=regularizers.L2(1e-4),
    activity_regularizer=regularizers.L2(1e-5)))
    
    model.add(Dense(units = hp_layer_2, activation = hp_activation, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4),
    bias_regularizer=regularizers.L2(1e-4),
    activity_regularizer=regularizers.L2(1e-5)))
    
    model.add(Dense(units = hp_layer_3, activation = hp_activation, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4),
    bias_regularizer=regularizers.L2(1e-4),
    activity_regularizer=regularizers.L2(1e-5)))
    
#     model.add(Dense(units = hp_layer_4, activation = hp_activation, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4),
#     bias_regularizer=regularizers.L2(1e-4),
#     activity_regularizer=regularizers.L2(1e-5)))
    
    model.add(BatchNormalization())
    
    model.add(Dense(len(encoder_map["playlist_genre"]["uniques"]), activation = 'softmax'))
    model.compile(optimizer = keras.optimizers.Adam(learning_rate=hp_learning_rate),                  
                      loss='sparse_categorical_crossentropy', 
                      metrics = ['accuracy'] )
    return model

# %%
objective_value = 'val_accuracy'
monitor_value = 'val_loss'
trials = 10
restore_flag = True
patience_value = 2
validation_value = 0.21
project = 'playlistGenre_without_duration'
overwrite_bool = True
    
tuner = kt.BayesianOptimization(
    model_builder,
    objective = objective_value,
    max_trials=trials,
    directory='dir',
    overwrite=True,
    project_name=project
)

# %%
es = keras.callbacks.EarlyStopping(
                                   monitor = monitor_value,
                                   mode='auto',
                                   patience=patience_value, 
                                   restore_best_weights = restore_flag)

# %%
tuner.search(X_train, y_train, epochs = 150,
            validation_split = validation_value,
            callbacks = [es])

# %%
hyper_parameters = tuner.get_best_hyperparameters(num_trials = 1)[0]
model = tuner.hypermodel.build(hyper_parameters)

print(model)
history = model.fit(X_train, y_train, epochs = 10, 
                    validation_split = validation_value, 
                    shuffle = True,
                    callbacks = [es])
model.save("history.keras")

# %%
for k,v in hyper_parameters.values.items():
    print(f'{k} : {v}')

# %%
history_dict = history.history
print(history_dict.keys())

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, val_acc, label='Validation accuracy', color='blue')
plt.plot(epochs, acc, label='Training accuracy',color='orange')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(epochs, loss, label='Loss', color = 'red')
plt.plot(epochs, val_loss, label='Validation Loss', color = 'purple')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from kerastuner import HyperModel

# Save the tuner
tuner.save('dir/playlistGenre_without_duration')

# Save the best model
best_model = tuner.get_best_models(num_models=1)[0]
best_model.save('model')
